# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
from matplotlib.colors import LogNorm

# Chargement des axes
kpar = np.loadtxt("PS1_PS2_Data/bins_kpar.txt")
kperp = np.loadtxt("PS1_PS2_Data/bins_kper.txt")

files = sorted(glob.glob("PS1_PS2_Data/Pk_PS2_*.txt"))
z_ranges = [
    "z = 8.41 – 7.56",
    "z = 7.56 – 6.85",
    "z = 6.85 – 6.25"
]
for i,f in enumerate(files):
    data = np.loadtxt(f)
    
    plt.figure(figsize=(8, 7))
    
    # pcolormesh avec shading='flat' ou 'nearest' affiche les données brutes
    # On définit les limites des axes pour correspondre aux vecteurs k  
    pcm = plt.pcolormesh(kperp, kpar, data, 
                         norm=LogNorm(vmin=data.min(), vmax=data.max()),
                         cmap='viridis')
    plt.colorbar(pcm, label=r'$\Delta^2(k_\perp, k_\parallel)$ [mK$^2$]')
    plt.xlabel(r'$k_\perp$ [$h$/Mpc]')
    plt.ylabel(r'$k_\parallel$ [$h$/Mpc]')
    plt.title(f'Brightness Temperature Power Spectrum – {z_ranges[i]}, max = {data.max():.2e} K$^2$')    
    plt.tight_layout()
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
from matplotlib.colors import LogNorm

# Chargement des axes
kpar = np.loadtxt("PS1_PS2_Data/bins_kpar.txt")
kperp = np.loadtxt("PS1_PS2_Data/bins_kper.txt")

files = sorted(glob.glob("PS1_PS2_Data/Pk_PS_average*.txt"))
z_ranges = [
    "z = 8.41 – 7.56",
    "z = 7.56 – 6.85",  
    "z = 6.85 – 6.25"
]
for i,f in enumerate(files):
    data = np.loadtxt(f)
    
    plt.figure(figsize=(8, 7))
    
    # pcolormesh avec shading='flat' ou 'nearest' affiche les données brutes
    # On définit les limites des axes pour correspondre aux vecteurs k  
    pcm = plt.pcolormesh(kperp, kpar, data, 
                         norm=LogNorm(vmin=data.min(), vmax=data.max()),
                         cmap='viridis')
    plt.colorbar(pcm, label=r'$\Delta^2(k_\perp, k_\parallel)$ [mK$^2$]')
    plt.xlabel(r'$k_\perp$ [$h$/Mpc]')
    plt.ylabel(r'$k_\parallel$ [$h$/Mpc]')
    plt.title(f'Brightness Temperature Average Noise Power Spectrum – {z_ranges[i]}, max = {data.max():.2e} K$^2$')    
    plt.tight_layout()
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
from matplotlib.colors import LogNorm

# Chargement des axes
kpar = np.loadtxt("PS1_PS2_Data/bins_kpar.txt")
kperp = np.loadtxt("PS1_PS2_Data/bins_kper.txt")

files = sorted(glob.glob("PS1_PS2_Data/Pk_PS2_*.txt"))
z_ranges = [
    "z = 8.41 – 7.56",
    "z = 7.56 – 6.85",
    "z = 6.85 – 6.25"
]
for i,f in enumerate(files):
    data = np.loadtxt(f)
    
    plt.figure(figsize=(8, 7))
    
    # pcolormesh avec shading='flat' ou 'nearest' affiche les données brutes
    # On définit les limites des axes pour correspondre aux vecteurs k  
    pcm = plt.pcolormesh(kperp, kpar, data, 
                         norm=LogNorm(vmin=data.min(), vmax=data.max()),
                         cmap='viridis')
    plt.colorbar(pcm, label=r'$\Delta^2(k_\perp, k_\parallel)$ [mK$^2$]')
    plt.xlabel(r'$k_\perp$ [$h$/Mpc]')
    plt.ylabel(r'$k_\parallel$ [$h$/Mpc]')
    plt.title(f'Brightness Temperature Power Spectrum – {z_ranges[i]}, max = {data.max():.2e} K$^2$')    
    plt.tight_layout()
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
from matplotlib.colors import LogNorm

kpar = np.loadtxt("PS1_PS2_Data/bins_kpar.txt")
kperp = np.loadtxt("PS1_PS2_Data/bins_kper.txt")

files = sorted(glob.glob("PS1_PS2_Data/Pk_PS2_*.txt"))

z_ranges = [
    "7.96",
    "7.19",
    "6.54"
]
ps2_true_list = []
z_ranges_list = []
for i, f in enumerate(files):

    data = np.loadtxt(f)
    print(f"Data shape for {f}: {kpar}")
    ps2_true_list.append(data)
    z_ranges_list.append(z_ranges[i])
# Out:
# Data shape for PS1_PS2_Data/Pk_PS2_151.0_165.9.txt: [0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5 ]
# Data shape for PS1_PS2_Data/Pk_PS2_166.0_180.9.txt: [0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5 ]
# Data shape for PS1_PS2_Data/Pk_PS2_181.0_195.9.txt: [0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5 ]

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
from matplotlib.colors import LogNorm

kpar = np.loadtxt("PS1_PS2_Data/bins_kpar.txt")
kperp = np.loadtxt("PS1_PS2_Data/bins_kper.txt")

files = sorted(glob.glob("PS1_PS2_Data/Pk_PS1_*.txt"))

z_ranges = [
    "7.96",
    "7.19",
    "6.54"
]
ps1_true_list = []
z_ranges_list = []
for i, f in enumerate(files):

    data = np.loadtxt(f)
    print(f"Data shape for {f}: {kpar}")
    ps1_true_list.append(data)
    z_ranges_list.append(z_ranges[i])
# Out:
# Data shape for PS1_PS2_Data/Pk_PS1_151.0_165.9.txt: [0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5 ]
# Data shape for PS1_PS2_Data/Pk_PS1_166.0_180.9.txt: [0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5 ]
# Data shape for PS1_PS2_Data/Pk_PS1_181.0_195.9.txt: [0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5 ]

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
from matplotlib.colors import LogNorm

# Chargement des axes
kpar = np.loadtxt("PS1_PS2_Data/bins_kpar.txt")
kperp = np.loadtxt("PS1_PS2_Data/bins_kper.txt")

files = sorted(glob.glob("PS1_PS2_Data/err_Pk_PS2_*.txt"))
z_ranges = [
    "z = 8.41 – 7.56",
    "z = 7.56 – 6.85",
    "z = 6.85 – 6.25"
]
data2_list =[]
for i,f in enumerate(files):
    data = np.loadtxt(f)
    
    plt.figure(figsize=(8, 7))
    
    # pcolormesh avec shading='flat' ou 'nearest' affiche les données brutes
    # On définit les limites des axes pour correspondre aux vecteurs k
    data2 = data/ps2_true_list[i]
    data2_list.append(data2)
    pcm = plt.pcolormesh(kperp, kpar, data2, 
                         norm=LogNorm(vmin=data2.min(), vmax=data2.max()),
                         cmap='viridis')    
    plt.colorbar(pcm, label=r'$\Delta^2(k_\perp, k_\parallel)$ [mK$^2$]')
    plt.xlabel(r'$k_\perp$ [$h$/Mpc]')
    plt.ylabel(r'$k_\parallel$ [$h$/Mpc]')
    plt.title(f'{f} – {z_ranges[i]}')    
    plt.tight_layout()
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
from matplotlib.colors import LogNorm

# Chargement des axes
kpar = np.loadtxt("PS1_PS2_Data/bins_kpar.txt")
kperp = np.loadtxt("PS1_PS2_Data/bins_kper.txt")

files = sorted(glob.glob("PS1_PS2_Data/err_Pk_PS1_*.txt"))
z_ranges = [
    "z = 8.41 – 7.56",
    "z = 7.56 – 6.85",
    "z = 6.85 – 6.25"
]
data1_list= []
for i,f in enumerate(files):
    data = np.loadtxt(f)
    
    plt.figure(figsize=(8, 7))
    
    # pcolormesh avec shading='flat' ou 'nearest' affiche les données brutes
    # On définit les limites des axes pour correspondre aux vecteurs k
    data1 = data/ps1_true_list[i]
    pcm = plt.pcolormesh(kperp, kpar, data1, 
                         norm=LogNorm(vmin=data1.min(), vmax=data1.max()),
                         cmap='viridis')   
    data1_list.append(data1)
    plt.colorbar(pcm, label=r'$\Delta^2(k_\perp, k_\parallel)$ [mK$^2$]')
    plt.xlabel(r'$k_\perp$ [$h$/Mpc]')
    plt.ylabel(r'$k_\parallel$ [$h$/Mpc]')
    plt.title(f'{f} – {z_ranges[i]}')    
    plt.tight_layout()
    plt.show()

# %%
all_data = data1_list + data2_list
all_data_array = np.array(all_data)
for i in range(10):
    for j in range(10):
        valeur_std = all_data_array[:, i, j].std()
        moyenne = all_data_array[:, i, j].mean()
        print(f"Coefficient de variation en ({i}, {j}) : {(valeur_std/moyenne)*100:.4f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 all_data = data1_list*ps1_true_list + data2_list*ps2_true_list
#       2 all_data_array = np.array(all_data)
#       3 for i in range(10):
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
from matplotlib.colors import LogNorm

kpar = np.loadtxt("PS1_PS2_Data/bins_kpar.txt")
kperp = np.loadtxt("PS1_PS2_Data/bins_kper.txt")

files = sorted(glob.glob("PS1_PS2_Data/Pk_PS2_*.txt"))

# Redshift ranges corresponding to the frequency bands (same order as files)
z_ranges = [
    "z = 8.41 – 7.56",
    "z = 7.56 – 6.85",
    "z = 6.85 – 6.25"
]

for i, f in enumerate(files):

    data = np.loadtxt(f)

    k_total = np.sqrt(kperp**2 + kpar**2)

    plt.figure(figsize=(8, 6))
    plt.contourf(kperp, kpar, data, levels=50, cmap='viridis')
    plt.colorbar(label=r'$\Delta^2(k_\perp, k_\parallel)$ [mK$^2$]')
    
    plt.xlabel(r'$k_\perp$ [h/Mpc]')
    plt.ylabel(r'$k_\parallel$ [h/Mpc]')

    plt.title(f'Brightness Temperature Power Spectrum – {z_ranges[i]}')

    plt.show()
